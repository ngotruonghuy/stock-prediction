# %%
import pandas as pd 
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import  LSTM
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout
import xgboost
import pickle
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4548/704007937.py in <module>
#       5 from tensorflow.keras.models import Sequential
#       6 from tensorflow.keras.layers import Dense
# ----> 7 from keras.layers import  LSTM
#       8 from sklearn.preprocessing import MinMaxScaler
#       9 from tensorflow.keras.models import load_model
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\__init__.py in <module>
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\models\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\functional.py in <module>
#      24 import tensorflow.compat.v2 as tf
#      25
# ---> 26 from keras import backend
#      27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\backend.py in <module>
#      32 from keras import backend_config
#      33 from keras.distribute import distribute_coordinator_utils as dc
# ---> 34 from keras.dtensor import dtensor_api as dtensor
#      35 from keras.engine import keras_tensor
#      36 from keras.utils import control_flow_util
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\dtensor\__init__.py in <module>
#      20 # Conditional import the dtensor API, since it is currently broken in OSS.
#      21 if _DTENSOR_API_ENABLED:
# ---> 22     from tensorflow.compat.v2.experimental import dtensor as dtensor_api
#      23 else:
#      24     # Leave it with a placeholder, so that the import line from other python
#
# ImportError: cannot import name 'dtensor' from 'tensorflow.compat.v2.experimental' (C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\_api\v2\compat\v2\experimental\__init__.py)

# %% [markdown]
# **Stock price prediction in 15 minutes for Microsoft, combining models and indicators.**

# %% [markdown]
# # DATA COLLECTION

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='D8JHWTNSXO7M9VKV', output_format='pandas')

# %%
data = ts.get_intraday(symbol='MSFT',interval='15min', outputsize='full')
data = data[0]
data.rename(lambda x: x[2:].strip(), axis='columns', inplace=True)
data
# Out:
#                        open    high     low   close   volume
# date
# 2023-06-26 19:45:00  329.70  330.00  329.50  329.74   3637.0
# 2023-06-26 19:30:00  329.76  330.00  329.50  329.70   4756.0
# 2023-06-26 19:15:00  329.53  330.00  328.60  329.84  23647.0
# 2023-06-26 19:00:00  329.08  329.74  328.87  329.52   6428.0
# 2023-06-26 18:45:00  329.00  329.29  328.81  328.82    954.0
# ...                     ...     ...     ...     ...      ...
# 2023-05-30 05:00:00  336.30  336.70  336.00  336.35   8878.0
# 2023-05-30 04:45:00  337.17  337.17  336.00  336.41   9615.0
# 2023-05-30 04:30:00  336.32  337.43  336.25  337.17  12467.0
# 2023-05-30 04:15:00  335.72  337.00  335.70  336.52  23289.0
# 2023-05-30 04:00:00  335.65  335.99  334.20  335.70  22617.0
#
# [1216 rows x 5 columns]

# %% [markdown]
# # INDICATORS CALCULATION

# %%
from alpha_vantage.techindicators import TechIndicators
ti = TechIndicators(key='D8JHWTNSXO7M9VKV', output_format='pandas')

# %% [markdown]
# ## 1. Rate of Change (ROC)

# %%
indicator_roc = ti.get_roc(symbol='MSFT', interval='15min', time_period=20)
indicator_roc = indicator_roc[0]
indicator_roc
# Out:
#                         ROC
# date
# 2023-05-30 09:00:00  0.3038
# 2023-05-30 09:15:00 -0.3893
# 2023-05-30 09:30:00 -0.4864
# 2023-05-30 09:45:00 -1.3555
# 2023-05-30 10:00:00 -1.5460
# ...                     ...
# 2023-06-26 18:45:00 -0.3485
# 2023-06-26 19:00:00 -0.1681
# 2023-06-26 19:15:00 -0.0364
# 2023-06-26 19:30:00 -0.3867
# 2023-06-26 19:45:00 -0.1907
#
# [1196 rows x 1 columns]

# %% [markdown]
# ## 2. Simple Moving Average (SMA)

# %%
indicator_sma = ti.get_sma(symbol='MSFT', interval='15min', time_period=20)
indicator_sma = indicator_sma[0]
indicator_sma
# Out:
#                           SMA
# date
# 2023-05-30 08:45:00  336.6495
# 2023-05-30 09:00:00  336.7005
# 2023-05-30 09:15:00  336.6350
# 2023-05-30 09:30:00  336.5530
# 2023-05-30 09:45:00  336.3250
# ...                       ...
# 2023-06-26 18:45:00  329.3116
# 2023-06-26 19:00:00  329.2839
# 2023-06-26 19:15:00  329.2779
# 2023-06-26 19:30:00  329.2139
# 2023-06-26 19:45:00  329.1824
#
# [1197 rows x 1 columns]

# %% [markdown]
# ## 3. Relative Strength Index (RSI)

# %%
indicator_rsi = ti.get_rsi(symbol='MSFT', interval='15min', time_period=20)
indicator_rsi = indicator_rsi[0]
indicator_rsi

# %% [markdown]
# ## 4. Bolling Bands (BBANDS)

# %%
def BollingerBand(data, n_loockback, n_std=2):
    hlc_avg = (data.high + data.low + data.close)/3
    data_std = hlc_avg.rolling(window=n_loockback).std()
    data_upper = data.SMA + n_std * data_std
    data_lower = data.SMA - n_std * data_std
    return data.SMA, data_lower, data_upper

# %%
# indicator_bb = ti.get_bbands(symbol='MSFT', interval='15min', time_period=20)
# indicator_bb = indicator_bb[0]
# indicator_bb

# %% [markdown]
# **Merge indicators to data**

# %%
original_df = pd.merge(data, indicator_roc, on='date', how='inner')
original_df = pd.merge(original_df, indicator_sma, on='date', how='inner')
original_df = pd.merge(original_df, indicator_rsi, on='date', how='inner')
# original_df = pd.merge(original_df, indicator_bb, on='date', how='inner')
original_df["Real Middle Band"], original_df["Real Lower Band"], original_df["Real Upper Band"] = BollingerBand(original_df, 20, 2)
original_df = original_df.dropna()
original_df = original_df.iloc[::-1]
original_df.to_csv('./DATA/MSFT.csv')
original_df
# Out:
#                        open     high     low    close     volume     ROC  \
# date
# 2023-05-30 09:00:00  336.65  336.800  336.45  336.720    36329.0  0.3038
# 2023-05-30 09:15:00  336.63  337.000  334.80  335.210    99194.0 -0.3893
# 2023-05-30 09:30:00  335.23  335.740  332.88  335.530  4039489.0 -0.4864
# 2023-05-30 09:45:00  335.56  335.580  330.58  331.850  2107766.0 -1.3555
# 2023-05-30 10:00:00  331.80  332.131  330.59  331.150  1311465.0 -1.5460
# ...                     ...      ...     ...      ...        ...     ...
# 2023-06-26 14:00:00  329.96  330.365  329.70  330.075   445942.0 -1.4731
# 2023-06-26 14:15:00  330.06  330.080  329.52  329.960   366852.0 -1.2125
# 2023-06-26 14:30:00  329.94  331.000  329.87  330.980   467913.0 -1.0996
# 2023-06-26 14:45:00  330.97  331.000  330.29  330.370   363906.0 -1.5026
# 2023-06-26 15:00:00  330.38  330.430  329.78  329.915   478434.0 -1.7145
#
#                           SMA      RSI  Real Middle Band  Real Lower Band  \
# date
# 2023-05-30 09:00:00  336.7005  58.4437          336.7005       333.767873
# 2023-05-30 09:15:00  336.6350  46.2679          336.6350       334.292771
# 2023-05-30 09:30:00  336.5530  48.6542          336.5530       334.773484
# 2023-05-30 09:45:00  336.3250  31.6431          336.3250       334.961857
# 2023-05-30 10:00:00  336.0650  29.5728          336.0650       334.710192
# ...                       ...      ...               ...              ...
# 2023-06-26 14:00:00  332.0485  35.6387          332.0485       330.466112
# 2023-06-26 14:15:00  331.8460  35.1969          331.8460       330.279465
# 2023-06-26 14:30:00  331.6620  41.9190          331.6620       330.103414
# 2023-06-26 14:45:00  331.4100  39.3495          331.4100       329.937022
# 2023-06-26 15:00:00  331.1223  37.5426          331.1223       329.734206
#
#                      Real Upper Band
# date
# 2023-05-30 09:00:00       339.633127
# 2023-05-30 09:15:00       338.977229
# 2023-05-30 09:30:00       338.332516
# 2023-05-30 09:45:00       337.688143
# 2023-05-30 10:00:00       337.419808
# ...                              ...
# 2023-06-26 14:00:00       333.630888
# 2023-06-26 14:15:00       333.412535
# 2023-06-26 14:30:00       333.220586
# 2023-06-26 14:45:00       332.882978
# 2023-06-26 15:00:00       332.510394
#
# [1177 rows x 11 columns]

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# ## 1. LSTM

# %% [markdown]
# ### a. Prepare Input

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close']].values
dataset
# Out:
# array([[336.72 ],
#        [335.21 ],
#        [335.53 ],
#        ...,
#        [330.98 ],
#        [330.37 ],
#        [329.915]])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[0.50536553],
#        [0.45472837],
#        [0.46545942],
#        ...,
#        [0.31287726],
#        [0.29242119],
#        [0.27716298]])

# %%
X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])
print(len(X))
print(len(y))
# Out:
# 1117
# 1117

# %%
X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])
print("Size train: ", X_train.shape)
print("Size validate: ", X_val.shape)
print("Size test: ", X_test.shape)
# Out:
# Size train:  (894, 60, 1)
# Size validate:  (112, 60, 1)
# Size test:  (111, 60, 1)

# %% [markdown]
# ### b. Train Model

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM.h5")
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 33ms/step - loss: 0.0308 - val_loss: 0.0026
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 3/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 4/20
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 5/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 8/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 9.1714e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 9.4047e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 8.4180e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 8.4579e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.1496e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 7.8222e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 8.6470e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 17/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.1534e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.0205e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 9.2848e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 7.8813e-04

# %% [markdown]
# ### c. Test Model

# %%
model_lstm = load_model('./MODEL/LSTM.h5')

# %%
predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions
prediction_df
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                      date    open     high     low    close    volume     ROC  \
# 1066  2023-06-22 19:30:00  340.31  340.400  340.18  340.270    4121.0  0.4991
# 1067  2023-06-22 19:45:00  340.28  340.400  339.62  339.620    6694.0  0.2024
# 1068  2023-06-23 04:00:00  338.02  338.980  337.79  338.000    3293.0 -0.2597
# 1069  2023-06-23 04:15:00  338.00  338.040  337.38  337.440    1654.0 -0.3485
# 1070  2023-06-23 04:30:00  337.50  337.970  337.50  337.770    1242.0 -0.4412
# ...                   ...     ...      ...     ...      ...       ...     ...
# 1172  2023-06-26 14:00:00  329.96  330.365  329.70  330.075  445942.0 -1.4731
# 1173  2023-06-26 14:15:00  330.06  330.080  329.52  329.960  366852.0 -1.2125
# 1174  2023-06-26 14:30:00  329.94  331.000  329.87  330.980  467913.0 -1.0996
# 1175  2023-06-26 14:45:00  330.97  331.000  330.29  330.370  363906.0 -1.5026
# 1176  2023-06-26 15:00:00  330.38  330.430  329.78  329.915  478434.0 -1.7145
#
#            SMA      RSI  Real Middle Band  Real Lower Band  Real Upper Band  \
# 1066  339.8570  65.8028          339.8570       338.036420       341.677580
# 1067  339.8913  58.1992          339.8913       338.335483       341.447117
# 1068  339.8473  44.6605          339.8473       338.361414       341.333186
# 1069  339.7883  41.1752          339.7883       338.074026       341.502574
# 1070  339.7135  43.8913          339.7135       337.913969       341.513031
# ...        ...      ...               ...              ...              ...
# 1172  332.0485  35.6387          332.0485       330.466112       333.630888
# 1173  331.8460  35.1969          331.8460       330.279465       333.412535
# 1174  331.6620  41.9190          331.6620       330.103414       333.220586
# 1175  331.4100  39.3495          331.4100       329.937022       332.882978
# 1176  331.1223  37.5426          331.1223       329.734206       332.510394
#
#       predictions
# 1066   340.025726
# 1067   340.039154
# 1068   339.931641
# 1069   339.520081
# 1070   338.927734
# ...           ...
# 1172   329.504303
# 1173   329.511810
# 1174   329.538544
# 1175   329.708160
# 1176   329.857819
#
# [111 rows x 13 columns]

# %%
plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# ### d. Combine Indicators

# %% [markdown]
# #### + ROC

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC']].values
dataset
# Out:
# array([[ 3.36720e+02,  3.03800e-01],
#        [ 3.35210e+02, -3.89300e-01],
#        [ 3.35530e+02, -4.86400e-01],
#        ...,
#        [ 3.30980e+02, -1.09960e+00],
#        [ 3.30370e+02, -1.50260e+00],
#        [ 3.29915e+02, -1.71450e+00]])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[0.50536553, 0.52491186],
#        [0.45472837, 0.41433608],
#        [0.46545942, 0.39884495],
#        ...,
#        [0.31287726, 0.30101626],
#        [0.29242119, 0.23672245],
#        [0.27716298, 0.20291635]])

# %%
X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])
print(len(X))
print(len(y))
# Out:
# 1117
# 1117

# %%
X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])
print("Size train: ", X_train.shape)
print("Size validate: ", X_val.shape)
print("Size test: ", X_test.shape)
# Out:
# Size train:  (894, 60, 2)
# Size validate:  (112, 60, 2)
# Size test:  (111, 60, 2)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], 2)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_ROC.h5")
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 31ms/step - loss: 0.0390 - val_loss: 0.0049
# Epoch 2/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 9.7426e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 9.3452e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 8.5327e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 9.7049e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 9.2853e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.6849e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.5786e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.4256e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.4505e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 8.8486e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.0522e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 7.1355e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.2679e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 8.5841e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0011

# %%
model_lstm = load_model('./MODEL/LSTM_ROC.h5')

# %%
predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]
predictions
# Out:
# array([339.82788, 339.79916, 339.62592, 339.15366, 338.57593, 338.06067,
#        337.47736, 337.06   , 336.7664 , 336.6032 , 336.5735 , 336.5533 ,
#        336.52594, 336.52234, 336.5358 , 336.66205, 336.769  , 336.81146,
#        336.68915, 336.55588, 336.30582, 335.95935, 335.56107, 335.29208,
#        335.0229 , 334.87012, 334.7903 , 334.78635, 334.8707 , 335.13538,
#        335.27322, 335.3075 , 335.2161 , 335.19083, 335.15933, 335.14493,
#        335.2276 , 335.396  , 335.6976 , 336.04077, 336.41306, 336.70294,
#        336.9044 , 336.94876, 336.94104, 336.6353 , 336.25446, 335.86322,
#        335.50537, 335.26352, 334.978  , 334.73895, 334.58228, 334.44836,
#        334.37128, 334.31955, 334.27078, 334.2269 , 334.14423, 334.03845,
#        333.96954, 333.95447, 333.9701 , 334.0224 , 334.06644, 334.18344,
#        334.3223 , 334.39142, 334.37943, 334.29056, 334.23706, 334.2088 ,
#        334.1151 , 334.05966, 334.0176 , 333.96124, 333.8792 , 333.81424,
#        333.80603, 333.86838, 333.915  , 333.97363, 334.02435, 333.95294,
#        333.89508, 333.83655, 333.80997, 333.90704, 333.8784 , 333.91095,
#        334.10443, 334.36505, 334.55716, 334.3875 , 334.24292, 333.84662,
#        333.2384 , 332.55548, 331.9571 , 331.2484 , 330.73206, 330.20828,
#        329.90106, 329.71048, 329.6144 , 329.52316, 329.45053, 329.38174,
#        329.3798 , 329.51553, 329.54694], dtype=float32)

# %%
prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions
prediction_df
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                      date    open     high     low    close    volume     ROC  \
# 1066  2023-06-22 19:30:00  340.31  340.400  340.18  340.270    4121.0  0.4991
# 1067  2023-06-22 19:45:00  340.28  340.400  339.62  339.620    6694.0  0.2024
# 1068  2023-06-23 04:00:00  338.02  338.980  337.79  338.000    3293.0 -0.2597
# 1069  2023-06-23 04:15:00  338.00  338.040  337.38  337.440    1654.0 -0.3485
# 1070  2023-06-23 04:30:00  337.50  337.970  337.50  337.770    1242.0 -0.4412
# ...                   ...     ...      ...     ...      ...       ...     ...
# 1172  2023-06-26 14:00:00  329.96  330.365  329.70  330.075  445942.0 -1.4731
# 1173  2023-06-26 14:15:00  330.06  330.080  329.52  329.960  366852.0 -1.2125
# 1174  2023-06-26 14:30:00  329.94  331.000  329.87  330.980  467913.0 -1.0996
# 1175  2023-06-26 14:45:00  330.97  331.000  330.29  330.370  363906.0 -1.5026
# 1176  2023-06-26 15:00:00  330.38  330.430  329.78  329.915  478434.0 -1.7145
#
#            SMA      RSI  Real Middle Band  Real Lower Band  Real Upper Band  \
# 1066  339.8570  65.8028          339.8570       338.036420       341.677580
# 1067  339.8913  58.1992          339.8913       338.335483       341.447117
# 1068  339.8473  44.6605          339.8473       338.361414       341.333186
# 1069  339.7883  41.1752          339.7883       338.074026       341.502574
# 1070  339.7135  43.8913          339.7135       337.913969       341.513031
# ...        ...      ...               ...              ...              ...
# 1172  332.0485  35.6387          332.0485       330.466112       333.630888
# 1173  331.8460  35.1969          331.8460       330.279465       333.412535
# 1174  331.6620  41.9190          331.6620       330.103414       333.220586
# 1175  331.4100  39.3495          331.4100       329.937022       332.882978
# 1176  331.1223  37.5426          331.1223       329.734206       332.510394
#
#       predictions
# 1066   339.827881
# 1067   339.799164
# 1068   339.625916
# 1069   339.153656
# 1070   338.575928
# ...           ...
# 1172   329.450531
# 1173   329.381744
# 1174   329.379791
# 1175   329.515533
# 1176   329.546936
#
# [111 rows x 13 columns]

# %%
plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], 2)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 31ms/step - loss: 0.0255 - val_loss: 0.0037
# Epoch 2/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 3/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 7/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 9.3417e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 10/20
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0017 - val_loss: 9.6218e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 12/20
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 8.9520e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.9685e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.8543e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.4858e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 8.2670e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 9.0986e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 7.1334e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], 2)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_RSI.h5")

model_lstm = load_model('./MODEL/LSTM_RSI.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 3s 34ms/step - loss: 0.0286 - val_loss: 0.0032
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 9.5695e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 8.2298e-04
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 7.4179e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 7.2201e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 9.1820e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.8677e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 6.7878e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 8.1043e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 12/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0013 - val_loss: 8.5322e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 8.3828e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.2153e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 6.4773e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 8.6093e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 7.8382e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 6.6945e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.6231e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 34ms/step - loss: 0.0154 - val_loss: 0.0025
# Epoch 2/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 4/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 9.8917e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 9.9970e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 9.7395e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 11/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 8.0997e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.7653e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 8.4513e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0013 - val_loss: 9.6059e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.8108e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 6.5506e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 9.2738e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 6.7354e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 6.0032e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + ROC

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_ROC.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_ROC.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 34ms/step - loss: 0.0244 - val_loss: 0.0028
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 3/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 9.6693e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 9.3408e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 9.5122e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 8.8411e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 9.4060e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 7.7784e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.5281e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 15/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.2465e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 9.0252e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 9.8745e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 6.4735e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 6.7436e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.9725e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_RSI.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_RSI.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 33ms/step - loss: 0.0151 - val_loss: 0.0022
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0026 - val_loss: 8.4838e-04
# Epoch 3/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 4/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 6.9653e-04
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.3887e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.9712e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.7132e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 6.8213e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.7836e-04 - val_loss: 6.3051e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 20ms/step - loss: 9.4216e-04 - val_loss: 6.4946e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.0080e-04 - val_loss: 5.8832e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 20ms/step - loss: 8.5145e-04 - val_loss: 7.9339e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.4376e-04 - val_loss: 6.1988e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 20ms/step - loss: 9.5259e-04 - val_loss: 7.0204e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 19ms/step - loss: 7.7483e-04 - val_loss: 6.0632e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 7.8135e-04 - val_loss: 5.5703e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 19ms/step - loss: 7.9921e-04 - val_loss: 5.8267e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 6.6208e-04 - val_loss: 5.7753e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 19ms/step - loss: 6.8355e-04 - val_loss: 5.2271e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 7.2079e-04 - val_loss: 0.0013
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 3s 35ms/step - loss: 0.0175 - val_loss: 0.0022
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 4/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 5/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 7/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 9.4836e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 8.8869e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 12/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 8.7983e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 14/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.9078e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.6082e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 9.5208e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 8.9493e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 6.8752e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 6.7287e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + ROC + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_ROC_RSI.h5")

model_lstm = load_model('./MODEL/LSTM_ROC_RSI.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 34ms/step - loss: 0.0363 - val_loss: 0.0035
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0036 - val_loss: 8.9734e-04
# Epoch 3/20
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0019 - val_loss: 8.0902e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 7.5404e-04
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 7/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 8.2555e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.1648e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 7.5087e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 6.2268e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 6.4735e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 8.1333e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 6.1205e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 8.4848e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0011 - val_loss: 5.6196e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 25ms/step - loss: 9.3749e-04 - val_loss: 5.5046e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 25ms/step - loss: 9.0959e-04 - val_loss: 5.9457e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 25ms/step - loss: 8.7062e-04 - val_loss: 0.0010
# Epoch 19/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 20/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 7.8051e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + ROC + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_ROC_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_ROC_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_RSI_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_RSI_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 3s 34ms/step - loss: 0.0209 - val_loss: 0.0018
# Epoch 2/20
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0032 - val_loss: 8.3103e-04
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 8.0522e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 6.9902e-04
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 9.8853e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 9.5374e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 8/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 8.0211e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0018 - val_loss: 7.3192e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 6.6347e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0012 - val_loss: 6.5737e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 6.3289e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.7614e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 6.3282e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 6.3424e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 6.1960e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 6.2958e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.9922e-04 - val_loss: 6.0633e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 6.6925e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.2816e-04 - val_loss: 6.1465e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + ROC + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_ROC_RSI.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_ROC_RSI.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 33ms/step - loss: 0.0310 - val_loss: 0.0026
# Epoch 2/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 4/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 7.7440e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 7.5190e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 10/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 7.2831e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.2814e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 8.1860e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.0514e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 7.5592e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 6.6795e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.4299e-04 - val_loss: 9.6236e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 5.9125e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 8.6016e-04 - val_loss: 5.4326e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 20ms/step - loss: 8.0478e-04 - val_loss: 5.6372e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + ROC + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_ROC_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_ROC_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 3s 34ms/step - loss: 0.0403 - val_loss: 0.0119
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0072 - val_loss: 0.0029
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 7/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 9.8631e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 9.0224e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 9.7421e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 9.0326e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 7.9278e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 8.8647e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.8054e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.2777e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 7.4623e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 6.5342e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 6.6171e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 7.9306e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_RSI_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_RSI_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 34ms/step - loss: 0.0368 - val_loss: 0.0044
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0048 - val_loss: 0.0020
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0028 - val_loss: 9.9816e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 9.5109e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 9.0928e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 7.6223e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 8.8054e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 7.3642e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 7.5185e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 7.0923e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 7.8819e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 7.1132e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 7.1758e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 8.8914e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.8638e-04 - val_loss: 8.0009e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 9.2855e-04 - val_loss: 0.0011
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 0.0011
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + ROC + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_ROC_RSI_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_ROC_RSI_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 3s 34ms/step - loss: 0.0220 - val_loss: 0.0037
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 7.9310e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 8.9595e-04
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 6.6212e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 6.3712e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 6.1694e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 5.8979e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 6.7909e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 5.5418e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 5.5085e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.8254e-04 - val_loss: 5.2638e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.5330e-04 - val_loss: 5.1869e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 19ms/step - loss: 8.3937e-04 - val_loss: 6.7058e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 7.8714e-04 - val_loss: 4.9843e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 7.9743e-04 - val_loss: 4.8484e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 8.6302e-04 - val_loss: 4.9936e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 19ms/step - loss: 7.3185e-04 - val_loss: 4.7336e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 18ms/step - loss: 6.8461e-04 - val_loss: 4.7049e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### + BBANDS + ROC + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (X_train.shape[1], dataset.shape[1])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation=None))
model.add(Dense(1, activation=None))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/LSTM_BBANDS_ROC_RSI_SMA.h5")

model_lstm = load_model('./MODEL/LSTM_BBANDS_ROC_RSI_SMA.h5')

predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 2s 33ms/step - loss: 0.0307 - val_loss: 0.0097
# Epoch 2/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 3/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0024 - val_loss: 9.7075e-04
# Epoch 4/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 5/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 7.8431e-04
# Epoch 6/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 8.1552e-04
# Epoch 7/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 6.4621e-04
# Epoch 8/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 6.2101e-04
# Epoch 9/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 6.0856e-04
# Epoch 10/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 5.9324e-04
# Epoch 11/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 5.4760e-04
# Epoch 12/20
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 5.9962e-04
# Epoch 13/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 5.3817e-04
# Epoch 14/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.5159e-04 - val_loss: 9.3920e-04
# Epoch 15/20
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 7.0823e-04
# Epoch 16/20
# 28/28 [==============================] - 1s 19ms/step - loss: 9.2508e-04 - val_loss: 7.2554e-04
# Epoch 17/20
# 28/28 [==============================] - 1s 20ms/step - loss: 8.2647e-04 - val_loss: 5.6935e-04
# Epoch 18/20
# 28/28 [==============================] - 1s 19ms/step - loss: 8.1775e-04 - val_loss: 5.8144e-04
# Epoch 19/20
# 28/28 [==============================] - 1s 20ms/step - loss: 8.1691e-04 - val_loss: 5.1786e-04
# Epoch 20/20
# 28/28 [==============================] - 1s 19ms/step - loss: 8.2906e-04 - val_loss: 5.0002e-04
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ### e. Predict Future

# %%
def lstm_predict_future(data, modelName, indicatorArr, period):
    modelFileName = './MODEL/' + modelName
    sorted(indicatorArr)
    for indicator in indicatorArr:
        if indicator == 'close':
            continue
        modelFileName = modelFileName + '_' + indicator
    modelFileName = modelFileName + '.h5'
    model = load_model(modelFileName)
    numDataPoint = int(period / 15)
    
    data = data[indicatorArr].values
    data = data[-60:]

    scaler = MinMaxScaler(feature_range=(0,1))
    scaledData = scaler.fit_transform(data)

    modelInput = scaledData.reshape(-1, scaledData.shape[0], scaledData.shape[1])

    predictedScaledValue = model.predict(modelInput)

    predictedValue = scaler.inverse_transform(np.tile(predictedScaledValue, (1, scaledData.shape[1])))[:, 0]
    
    return predictedValue

# %% [markdown]
# ## 2. RNN

# %% [markdown]
# ### a. Prepare Input

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close']].values
dataset
# Out:
# array([[336.72 ],
#        [335.21 ],
#        [335.53 ],
#        ...,
#        [330.98 ],
#        [330.37 ],
#        [329.915]])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)
dataset

# %%
X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])
print(len(X))
print(len(y))
# Out:
# 1117
# 1117

# %%
X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])
print("Size train: ", X_train.shape)
print("Size validate: ", X_val.shape)
print("Size test: ", X_test.shape)
# Out:
# Size train:  (894, 60, 1)
# Size validate:  (112, 60, 1)
# Size test:  (111, 60, 1)

# %% [markdown]
# ### b. Train Model

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN.h5")
# Out:
# Epoch 1/25
# 28/28 [==============================] - 5s 63ms/step - loss: 108992.4766 - val_loss: 108054.4922
# Epoch 2/25
# 28/28 [==============================] - 1s 42ms/step - loss: 105426.6328 - val_loss: 105758.5234
# Epoch 3/25
# 28/28 [==============================] - 1s 42ms/step - loss: 103829.0547 - val_loss: 104522.0391
# Epoch 4/25
# 28/28 [==============================] - 1s 42ms/step - loss: 102681.9688 - val_loss: 103461.5469
# Epoch 5/25
# 28/28 [==============================] - 1s 41ms/step - loss: 101652.8672 - val_loss: 102457.6406
# Epoch 6/25
# 28/28 [==============================] - 1s 40ms/step - loss: 100682.2344 - val_loss: 101489.5625
# Epoch 7/25
# 28/28 [==============================] - 1s 41ms/step - loss: 99720.0625 - val_loss: 100540.4453
# Epoch 8/25
# 28/28 [==============================] - 1s 40ms/step - loss: 98800.4688 - val_loss: 99613.2109
# Epoch 9/25
# 28/28 [==============================] - 1s 40ms/step - loss: 97884.5469 - val_loss: 98700.4609
# Epoch 10/25
# 28/28 [==============================] - 1s 40ms/step - loss: 97034.8516 - val_loss: 97800.2969
# Epoch 11/25
# 28/28 [==============================] - 1s 40ms/step - loss: 96114.7734 - val_loss: 96910.9844
# Epoch 12/25
# 28/28 [==============================] - 1s 42ms/step - loss: 95178.8281 - val_loss: 96028.9375
# Epoch 13/25
# 28/28 [==============================] - 1s 41ms/step - loss: 94351.1875 - val_loss: 95156.7266
# Epoch 14/25
# 28/28 [==============================] - 1s 42ms/step - loss: 93445.3672 - val_loss: 94293.1094
# Epoch 15/25
# 28/28 [==============================] - 1s 41ms/step - loss: 92645.4062 - val_loss: 93438.7500
# Epoch 16/25
# 28/28 [==============================] - 1s 41ms/step - loss: 91830.5469 - val_loss: 92592.1953
# Epoch 17/25
# 28/28 [==============================] - 1s 41ms/step - loss: 90812.3672 - val_loss: 91748.9844
# Epoch 18/25
# 28/28 [==============================] - 1s 40ms/step - loss: 90046.6875 - val_loss: 90913.3516
# Epoch 19/25
# 28/28 [==============================] - 1s 40ms/step - loss: 89242.8438 - val_loss: 90085.0000
# Epoch 20/25
# 28/28 [==============================] - 1s 40ms/step - loss: 88472.1250 - val_loss: 89265.6797
# Epoch 21/25
# 28/28 [==============================] - 1s 40ms/step - loss: 87624.0391 - val_loss: 88451.8594
# Epoch 22/25
# 28/28 [==============================] - 1s 42ms/step - loss: 86853.8359 - val_loss: 87644.5156
# Epoch 23/25
# 28/28 [==============================] - 1s 41ms/step - loss: 86068.3672 - val_loss: 86842.8203
# Epoch 24/25
# 28/28 [==============================] - 1s 40ms/step - loss: 85204.7422 - val_loss: 86047.3984
# Epoch 25/25
# 28/28 [==============================] - 1s 40ms/step - loss: 84480.2266 - val_loss: 85258.5000

# %% [markdown]
# ### c. Test Model

# %%
model_rnn = load_model('./MODEL/RNN.h5')

# %%
predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19168/1844199228.py in <module>
#       1 predictions = model_rnn.predict(X_test)
# ----> 2 predictions = scaler.inverse_transform(predictions)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     459                         force_all_finite="allow-nan")
#     460
# --> 461         X -= self.min_
#     462         X /= self.scale_
#     463         return X
#
# ValueError: non-broadcastable output operand with shape (111,1) doesn't match the broadcast shape (111,7)

# %%
prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions
prediction_df

# %%
plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# ### d. Combine Indicators

# %% [markdown]
# #### + ROC

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC']].values
dataset

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)
dataset

# %%
X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])
print(len(X))
print(len(y))

# %%
X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])
print("Size train: ", X_train.shape)
print("Size validate: ", X_val.shape)
print("Size test: ", X_test.shape)

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],2)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_ROC.h5")

# %%
model_rnn = load_model('./MODEL/RNN_ROC.h5')

# %%
predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, 2)))[:, 0]

# %%
prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions
prediction_df

# %%
plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_SMA.h5")

model_rnn = load_model('./MODEL/RNN_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_RSI.h5")

model_rnn = load_model('./MODEL/RNN_RSI.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_ROC.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_ROC.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_RSI.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_RSI.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_SMA.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + ROC + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_ROC_RSI.h5")

model_rnn = load_model('./MODEL/RNN_ROC_RSI.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + ROC + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_ROC_SMA.h5")

model_rnn = load_model('./MODEL/RNN_ROC_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_RSI_SMA.h5")

model_rnn = load_model('./MODEL/RNN_RSI_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_ROC_RSI.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_ROC_RSI.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_ROC_SMA.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_ROC_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_RSI_SMA.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_RSI_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + ROC + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'ROC', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_ROC_RSI_SMA.h5")

model_rnn = load_model('./MODEL/RNN_ROC_RSI_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI', 'SMA']].values

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

X, y = [], []
for i in range(60, len(dataset)):
    X.append(dataset[i-60:i][:])
    y.append(dataset[i][0])

X_train, y_train = np.array(X[:math.ceil(len(X)*0.8)]), np.array(y[:math.ceil(len(X)*0.8)])
X_val, y_val = np.array(X[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)]), np.array(y[math.ceil(len(X)*0.8):math.ceil(len(X)*0.9)])
X_test, y_test = np.array(X[math.ceil(len(X)*0.9):]), np.array(y[math.ceil(len(X)*0.9):])

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], dataset.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=25, batch_size=32, shuffle=True, validation_data=(X_val, y_val))
model.save("./MODEL/RNN_BBANDS_ROC_RSI_SMA.h5")

model_rnn = load_model('./MODEL/RNN_BBANDS_ROC_RSI_SMA.h5')

predictions = model_rnn.predict(X_test)
predictions = scaler.inverse_transform(np.tile(predictions, (1, dataset.shape[1])))[:, 0]

prediction_df = original_df.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# ## 3. XGBOOST

# %% [markdown]
# ### a. Prepare Input

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume']]
dataset

# %%
for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
dataset

# %%
dataset.dropna(inplace=True)
dataset

# %%
X = dataset.drop(['close', 'volume'], axis=1)
y = pd.DataFrame(dataset['close'])
print(X.shape)
print(y.shape)
X

# %%
X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]
print("Size train: ", X_train.shape)
print("Size test: ", X_test.shape)

# %% [markdown]
# ### b. Train Model

# %%
xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST.dat", "wb"))

# %% [markdown]
# ### c. Test Model

# %%
model_xgboost = pickle.load(open("./MODEL/XGBOOST.dat", "rb"))

# %%
predictions = model_xgboost.predict(X_test)
predictions

# %%
prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions
prediction_df

# %%
plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# ### d. Combine Indicators

# %% [markdown]
# #### + ROC

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'ROC']]
dataset

# %%
for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
dataset

# %%
dataset.dropna(inplace=True)
dataset

# %%
X = dataset.drop(['close', 'volume', 'ROC'], axis=1)
y = pd.DataFrame(dataset['close'])
print(X.shape)
print(y.shape)
X

# %%
X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]
print("Size train: ", X_train.shape)
print("Size test: ", X_test.shape)

# %%
xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_ROC.dat", "wb"))

# %%
model_xgboost = pickle.load(open("./MODEL/XGBOOST_ROC.dat", "rb"))

# %%
predictions = model_xgboost.predict(X_test)
predictions

# %%
prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions
prediction_df

# %%
plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["SMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'RSI']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'RSI'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_RSI.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_RSI.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)


dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_ROC.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_ROC.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_RSI.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_RSI.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["SMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + ROC + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'ROC', 'RSI']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'ROC', 'RSI'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_ROC_RSI.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_ROC_RSI.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + ROC + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'ROC', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["SMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'ROC', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_ROC_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_ROC_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'RSI', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)
    dataset["SMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'RSI', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_RSI_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_RSI_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC + RSI

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_ROC_RSI.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_ROC_RSI.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_ROC_RSI.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_ROC_RSI.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["SMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_ROC_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_ROC_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)
    dataset["RMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'RSI', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_RSI_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_RSI_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + ROC + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'ROC', 'RSI', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)
    dataset["SMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'ROC', 'RSI', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_ROC_RSI_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_ROC_RSI_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# #### + BBANDS + ROC + RSI + SMA

# %%
original_df = pd.read_csv("./DATA/MSFT.csv")
dataset = original_df
dataset = dataset[['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI', 'SMA']]

for i in range (1, 3):
    dataset["close_date_" + str(i)] = dataset.close.shift(i)
    dataset["volume_date_" + str(i)] = dataset.volume.shift(i)
    dataset["RLB_date_" + str(i)] = dataset['Real Lower Band'].shift(i)
    dataset["RMB_date_" + str(i)] = dataset['Real Middle Band'].shift(i)
    dataset["RUB_date_" + str(i)] = dataset['Real Upper Band'].shift(i)
    dataset["ROC_date_" + str(i)] = dataset.ROC.shift(i)
    dataset["RSI_date_" + str(i)] = dataset.RSI.shift(i)
    dataset["RMA_date_" + str(i)] = dataset.SMA.shift(i)

dataset.dropna(inplace=True)

X = dataset.drop(['close', 'volume', 'Real Lower Band', 'Real Middle Band', 'Real Upper Band', 'ROC', 'RSI', 'SMA'], axis=1)
y = pd.DataFrame(dataset['close'])

X_train, y_train = X[:math.ceil(len(X)*0.9)], y[:math.ceil(len(X)*0.9)]
X_test, y_test = X[math.ceil(len(X)*0.9):], y[math.ceil(len(X)*0.9):]

xgb = xgboost.XGBRegressor(n_estimators=100, 
                           max_depth=8, 
                           learning_rate=0.1,
                           min_child_weight=5,
                           subsample=0.1, 
                           colsample_bytree=1, 
                           colsample_bylevel=1,
                           gamma=0.3,
                           objective='reg:squarederror')
model = xgb.fit(X_train, y_train)
pickle.dump(model, open("./MODEL/XGBOOST_BBANDS_ROC_RSI_SMA.dat", "wb"))

model_xgboost = pickle.load(open("./MODEL/XGBOOST_BBANDS_ROC_RSI_SMA.dat", "rb"))

predictions = model_xgboost.predict(X_test)

prediction_df = dataset.iloc[-len(predictions):]
prediction_df['predictions'] = predictions

plt.figure(figsize = (20, 10))
plt.plot(original_df['close'][-300:])
plt.plot(prediction_df['predictions'])
plt.legend(['True price', 'Predict price'], loc = 'lower right')
plt.show()

# %% [markdown]
# ### Predict Future

# %%
def xgboost_predict_future(data, modelName, indicatorArr, period):
    modelFileName = './MODEL/' + modelName
    sorted(indicatorArr)
    for indicator in indicatorArr:
        if indicator == 'close':
            continue
        modelFileName = modelFileName + '_' + indicator
    modelFileName = modelFileName + '.dat'
    model = pickle.load(open(modelFileName, "rb"))
    numDataPoint = int(period / 15)
    
    temp = indicatorArr.copy()
    temp.append('volume')
    data = data[temp]
    data = data[-5:]
    
    X = pd.DataFrame({})
    for column in data.columns:
        n = len(data)
        for i in range(1, n + 1):
            X[column + '_date_' + str(i)] = [data.iloc[n - i][column]] 
    
    predictedValue = model.predict(X)
    
    return predictedValue
